# %% [markdown]
# # Modelagem de IA da FarmTech Solutions
#
# Notebook base do grupo para a atividade do Capitulo 10. Esta versao contem apenas a estrutura inicial do trabalho, com secoes organizadas para preenchimento posterior.
#
# **Integrantes:** preencher pelo grupo.
#
# **Objetivo:** analisar a base de produtos agricolas, descrever os principais padroes e comparar modelos preditivos para recomendar a cultura mais adequada.

# %% [markdown]
# ## Organizacao do notebook
#
# Este arquivo foi dividido nas seguintes partes:
#
# 1. Carga e preparacao inicial da base.
# 2. Analise exploratoria do dataset.
# 3. Analise descritiva com graficos.
# 4. Perfil ideal de solo e clima e comparacao entre 3 culturas.
# 5. Modelagem preditiva com 5 algoritmos.
# 6. Avaliacao e comparacao dos modelos.
# 7. Conclusoes finais.

# %%
# Imports basicos do projeto
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

warnings.filterwarnings("ignore")
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %%
# Carregamento da base
df = pd.read_csv("Atividade_Cap10_produtos_agricolas.csv")
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %% [markdown]
# ## 1. Analise exploratoria do dataset
#
# Nesta secao, registrar a exploracao inicial da base:
#
# - dimensoes do dataset;
# - tipos de dados;
# - verificacao de nulos e duplicados;
# - estatisticas descritivas iniciais.

# %%
# TODO: adicionar a exploracao inicial da base
# Sugestoes: df.shape, df.info(), df.describe(), df.isnull().sum(), df.duplicated().sum()

# %% [markdown]
# ## 2. Analise descritiva com graficos
#
# Inserir pelo menos 5 graficos com interpretacoes textuais sobre os principais achados dos dados.

# %%
# TODO: inserir os graficos e as analises descritivas

# %% [markdown]
# ## 3. Perfil ideal de solo e clima
#
# Definir o perfil ideal com base nos dados e comparar 3 culturas escolhidas pelo grupo.
#
# Pontos esperados:
#
# - variaveis mais favoraveis para o cultivo;
# - comparacao entre as 3 culturas selecionadas;
# - apoio em analises estatisticas e visuais.

# %%
# TODO: calcular e comparar o perfil ideal de solo e clima

# %% [markdown]
# ## 4. Preparacao para modelagem
#
# Nesta parte, preparar os dados para treino e teste:
#
# - separacao entre variaveis explicativas e alvo;
# - codificacao da coluna alvo, se necessario;
# - divisao entre treino e teste;
# - normalizacao ou padronizacao, se fizer sentido.

# %%
# TODO: preparar os dados para a etapa de modelagem

# %% [markdown]
# ## 5. Modelos preditivos
#
# Reservar esta secao para os 5 algoritmos definidos pelo grupo. Sugestao inicial:
#
# - Decision Tree
# - Random Forest
# - KNN
# - SVM
# - Regressao Logistica

# %%
# TODO: treinar os modelos preditivos definidos pelo grupo

# %% [markdown]
# ## 6. Avaliacao e comparacao dos modelos
#
# Comparar os modelos com metricas pertinentes ao problema, como acuracia, precisao, recall e F1-score.

# %%
# TODO: consolidar metricas, comparar modelos e destacar limitacoes

# %% [markdown]
# ## 7. Conclusoes
#
# Sintetizar os principais achados do trabalho, os pontos fortes dos modelos e as limitacoes observadas durante a atividade.

# %% [markdown]
# ## Checklist de entrega
#
# Antes da entrega final, revisar:
#
# - celulas executadas;
# - comentarios em markdown explicando os resultados;
# - minimo de 5 graficos;
# - comparacao entre 5 modelos;
# - conclusoes finais do grupo.
